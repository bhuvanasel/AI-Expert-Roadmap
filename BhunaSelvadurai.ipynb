# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuvanasel/AI-Expert-Roadmap/blob/main/BhunaSelvadurai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python")
# Out:
# Hello, Python
